jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (129).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (13).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (130).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (131).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (132).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (133).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (134).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (135).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (136).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (137).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (138).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (139).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (14).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (140).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (141).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (142).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (143).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (144).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (145).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (146).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (147).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (148).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (149).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (15).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (150).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (151).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (152).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (153).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (154).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (155).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (156).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (157).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (158).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (159).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (16).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (160).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (161).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (162).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (163).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (164).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (165).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (166).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (167).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (168).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (169).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (17).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (170).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (171).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (172).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (173).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (174).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (175).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (176).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (177).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (178).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (179).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (18).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (180).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (181).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (182).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (183).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (184).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (185).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (186).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (187).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (188).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (189).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (19).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (190).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (191).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (192).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (193).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (194).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (195).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (196).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (197).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (198).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (199).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (2).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (20).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (200).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (201).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (202).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (203).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (204).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (205).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (206).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (207).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (208).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (209).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (21).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (210).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (211).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (212).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (213).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (214).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (215).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (216).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (217).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (218).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (219).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (22).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (220).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (221).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (222).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (223).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (224).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (225).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (226).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (227).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (228).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (229).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (23).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (230).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (231).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (232).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (233).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (234).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (235).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (236).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (237).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (238).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (239).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (24).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (240).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (241).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (242).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (243).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (244).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (245).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (246).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (247).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (248).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (249).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (25).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (250).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (251).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (252).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (253).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (254).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (255).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (256).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (257).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (258).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (259).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (26).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (260).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (261).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (262).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (263).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (264).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (27).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (28).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (29).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (3).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (30).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (31).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (32).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (33).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (34).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (35).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (36).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (37).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (38).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (39).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (4).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (40).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (41).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (42).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (43).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (44).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (45).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (46).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (47).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (48).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (49).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (5).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (50).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (51).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (52).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (53).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (54).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (55).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (56).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (57).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (58).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (59).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (6).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (60).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (61).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (62).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (63).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (64).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (65).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (66).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (67).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (68).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (69).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (7).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (70).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (71).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (72).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (73).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (74).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (75).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (76).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (77).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (78).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (79).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (8).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (80).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (81).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (82).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (83).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (84).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (85).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (86).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (87).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (88).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (89).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (9).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (90).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (91).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (92).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (93).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (94).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (95).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (96).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (97).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (98).jpg
#   inflating: Raw Dataset/Healthy Leaf/Healthy (99).jpg
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.23.0 typeguard-2.13.3

# %%
from keras.models import Model
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, GlobalMaxPooling2D, Dropout, Input
from keras.optimizers import Adam
from keras.losses import SparseCategoricalCrossentropy
import os
from glob import glob
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
import gc
from skimage import exposure
from scipy.ndimage import gaussian_filter

# Set data directory
train_data_directory = "/content/Raw Dataset"

# Define classes
classes = ["Cescospora Leaf Spot", "Golden Mosaic", "Healthy Leaf"]
num_classes = 3
img_size = 224

# Load training data with unsharp masking
def load_images_from_directory(directory, random_state=None):
    images = []
    labels = []

    for class_index, class_name in enumerate(classes):
        class_path = os.path.join(directory, class_name)
        image_files = glob(os.path.join(class_path, "*.jpg"))
        for image_file in image_files:
            image = cv2.imread(image_file)

            image = cv2.resize(image, (img_size, img_size))
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            images.append(image)
            labels.append(class_index)

    images = np.array(images)
    labels = np.array(labels)

    # Use train_test_split to shuffle and split the data
    x_train, x_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=random_state, stratify=labels)

    return x_train, y_train, x_test, y_test  # Return both training and test sets



# Load training data
x_train, y_train, x_test, y_test = load_images_from_directory(train_data_directory, random_state=42)



# Print shapes
print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (736, 224, 224, 3) - y_train shape: (736,)
# x_test shape: (184, 224, 224, 3) - y_test shape: (184,)

# %%
import os
from glob import glob
import cv2
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa
import math

# Set your data and parameters
input_shape = (224, 224, 3)
learning_rate = 0.0001
weight_decay = 0.0001
batch_size = 16
num_epochs = 10
image_size = 224
patch_size = 6
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 2
transformer_units = [projection_dim * 2, projection_dim]
transformer_layers = 8
mlp_head_units = [2048, 1024]
validation_split = 0.1
label_smoothing = 0.1

# Data Augmentation
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ],
    name="data_augmentation",
)

# Patching and Encoding layers
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super().__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super().__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# MultiHeadAttention with custom modifications
class MultiHeadAttention(tf.keras.layers.MultiHeadAttention):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.tau = tf.Variable(math.sqrt(float(self._key_dim)), trainable=True)

    def _compute_attention(self, query, key, value, attention_mask=None, training=None):
        query = tf.multiply(query, 1.0 / self.tau)
        attention_scores = tf.einsum(self._dot_product_equation, key, query)
        attention_scores = self._masked_softmax(attention_scores, attention_mask)
        attention_scores_dropout = self._dropout_layer(
            attention_scores, training=training
        )
        attention_output = tf.einsum(
            self._combine_equation, attention_scores_dropout, value
        )
        return attention_output, attention_scores

# MLP layer function
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# Create the ViT model
inputs = layers.Input(shape=input_shape)
augmented = data_augmentation(inputs)

patches = Patches(patch_size)(augmented)
encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

for _ in range(transformer_layers):
    x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    attention_output = MultiHeadAttention(
        num_heads=num_heads, key_dim=projection_dim, dropout=0.1
    )(x1, x1)
    x2 = layers.Add()([attention_output, encoded_patches])
    x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
    x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
    encoded_patches = layers.Add()([x3, x2])

representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
representation = layers.Flatten()(representation)
representation = layers.Dropout(0.5)(representation)
features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
logits = layers.Dense(num_classes)(features)

model = keras.Model(inputs=inputs, outputs=logits)

# Compile and train the model
optimizer = tfa.optimizers.AdamW(
    learning_rate=learning_rate, weight_decay=weight_decay
)

model.compile(
    optimizer=optimizer,
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[
        keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
        keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
    ],
)


# Training the model
checkpoint_filepath = "/tmp/checkpoint"
checkpoint_callback = keras.callbacks.ModelCheckpoint(
    checkpoint_filepath,
    monitor="val_accuracy",
    save_best_only=True,
    save_weights_only=True,
)

history = model.fit(
    x=x_train,
    y=y_train,
    batch_size=batch_size,
    epochs=num_epochs,
    validation_split=validation_split,
    callbacks=[checkpoint_callback],
)

# Loading the best weights
model.load_weights(checkpoint_filepath)

# Evaluate the model on the test set
test_loss, test_accuracy, test_top_5_accuracy = model.evaluate(x_test, y_test)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Top 5 Accuracy: {test_top_5_accuracy}")

# Save the trained model
# model.save("vit_classifier.h5")
# Out:
# Epoch 1/10
# 42/42 [==============================] - 78s 2s/step - loss: 13.2256 - accuracy: 0.3746 - top-5-accuracy: 1.0000 - val_loss: 4.3323 - val_accuracy: 0.3378 - val_top-5-accuracy: 1.0000
# Epoch 2/10
# 42/42 [==============================] - 53s 1s/step - loss: 7.7739 - accuracy: 0.4079 - top-5-accuracy: 1.0000 - val_loss: 3.4692 - val_accuracy: 0.4865 - val_top-5-accuracy: 1.0000
# Epoch 3/10
# 42/42 [==============================] - 69s 2s/step - loss: 3.3872 - accuracy: 0.5000 - top-5-accuracy: 1.0000 - val_loss: 1.6421 - val_accuracy: 0.5811 - val_top-5-accuracy: 1.0000
# Epoch 4/10
# 42/42 [==============================] - 52s 1s/step - loss: 1.6277 - accuracy: 0.5211 - top-5-accuracy: 1.0000 - val_loss: 0.7909 - val_accuracy: 0.6486 - val_top-5-accuracy: 1.0000
# Epoch 5/10
# 42/42 [==============================] - 59s 1s/step - loss: 0.9401 - accuracy: 0.5785 - top-5-accuracy: 1.0000 - val_loss: 0.7157 - val_accuracy: 0.6757 - val_top-5-accuracy: 1.0000
# Epoch 6/10
# 42/42 [==============================] - 50s 1s/step - loss: 0.9403 - accuracy: 0.5498 - top-5-accuracy: 1.0000 - val_loss: 0.7873 - val_accuracy: 0.6892 - val_top-5-accuracy: 1.0000
# Epoch 7/10
# 42/42 [==============================] - 21s 498ms/step - loss: 0.8973 - accuracy: 0.6088 - top-5-accuracy: 1.0000 - val_loss: 0.7410 - val_accuracy: 0.6622 - val_top-5-accuracy: 1.0000
# Epoch 8/10
# 42/42 [==============================] - 57s 1s/step - loss: 0.8327 - accuracy: 0.5982 - top-5-accuracy: 1.0000 - val_loss: 0.6900 - val_accuracy: 0.7027 - val_top-5-accuracy: 1.0000
# Epoch 9/10
# 42/42 [==============================] - 21s 506ms/step - loss: 0.7875 - accuracy: 0.6344 - top-5-accuracy: 1.0000 - val_loss: 0.7455 - val_accuracy: 0.6892 - val_top-5-accuracy: 1.0000
# Epoch 10/10
# 42/42 [==============================] - 21s 495ms/step - loss: 0.8374 - accuracy: 0.6088 - top-5-accuracy: 1.0000 - val_loss: 0.7399 - val_accuracy: 0.6757 - val_top-5-accuracy: 1.0000
# 6/6 [==============================] - 2s 254ms/step - loss: 0.6621 - accuracy: 0.7283 - top-5-accuracy: 1.0000
# Test Loss: 0.6621255278587341
# Test Accuracy: 0.72826087474823
# Test Top 5 Accuracy: 1.0

# %%
from keras.utils import to_categorical
from sklearn.metrics import precision_recall_curve, auc
import matplotlib.pyplot as plt

# Convert labels to one-hot encoding
y_test_one_hot = to_categorical(y_test, num_classes=num_classes)

# Get predicted probabilities for each class
y_pred_prob = model.predict(x_test)

# Flatten the arrays
y_test_flat = y_test_one_hot.ravel()
y_pred_prob_flat = y_pred_prob.ravel()

# Compute precision-recall curve
precision, recall, _ = precision_recall_curve(y_test_flat, y_pred_prob_flat)
pr_auc = auc(recall, precision)

# Plot the overall precision-recall curve
plt.figure(figsize=(8, 8))
plt.plot(recall, precision, label=f'Overall (AUC = {pr_auc:.2f})')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Overall Precision-Recall Curve')
plt.legend()
plt.show()
# Out:
# 6/6 [==============================] - 3s 258ms/step

# %%
# Plot the accuracy curves
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 12})
# Plot training accuracy and validation/test accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Testing Accuracy')
plt.title('Training and Testing Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Plot the accuracy curves
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 12})
# Plot training accuracy and validation/test accuracy
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Testing Loss')
plt.title('Training and Testing loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from scipy import interp

# Get the predicted probabilities for each class
y_pred_proba = model.predict([x_test])

# Compute the ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for class_index in range(num_classes):
    y_true_binary = y_test == class_index
    fpr[class_index], tpr[class_index], _ = roc_curve(y_true_binary, y_pred_proba[:, class_index])
    roc_auc[class_index] = auc(fpr[class_index], tpr[class_index])

# Plot the ROC curve for each class
plt.figure()
colors = ['blue', 'red', 'green', 'orange', 'purple']  # Adjust the colors as needed
for class_index in range(num_classes):
    plt.plot(fpr[class_index], tpr[class_index], color=colors[class_index], lw=2,
             label='ROC curve (area = %0.2f) for %s' % (roc_auc[class_index], classes[class_index]))
plt.rcParams.update({'font.size': 10})
plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# 6/6 [==============================] - 3s 255ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import load_model
# model = load_model("/content/trained_model.h5")
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Make predictions on the test set
predictions = np.argmax(model.predict([x_test]), axis=1)

# Generate confusion matrix
cm = confusion_matrix(y_test, predictions)
#"Col_Ade", "Col_Ben","lun_Ben","lun_Ade","lun_Squ"
# Plot the confusion matrix
# labels =["Field Cricket", "Jute Stem Weevil", "Spilosoma Obliqua", "Yellow Mite"]
labels = ["Cescospora Leaf Spot", "Golden Mosaic", "Healthy Leaf"] # The class labels
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
fig, ax = plt.subplots(figsize=(8, 8))
plt.rcParams.update({'font.size': 18})  # Adjust the figure size if needed
disp.plot(cmap=plt.cm.Blues, ax=ax)
# plt.title("Confusion Matrix")
plt.xticks(rotation=45)  # Rotate the x-axis tick labels by 45 degrees
plt.savefig('confusion_matrix6.png', format='png', bbox_inches='tight')
plt.show()
# Out:
# 6/6 [==============================] - 2s 250ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Get the predicted class labels for the test set
predictions = model.predict([x_test])
predicted_labels = np.argmax(predictions, axis=1)

# Calculate the accuracy, precision, recall, and F1-score for each class
class_accuracies = []
class_precisions = []
class_recalls = []
class_f1_scores = []
for class_index in range(num_classes):
    y_true_binary = y_test == class_index
    predictions_binary = predicted_labels == class_index
    class_accuracy = accuracy_score(y_true_binary, predictions_binary)
    class_precision = precision_score(y_true_binary, predictions_binary)
    class_recall = recall_score(y_true_binary, predictions_binary)
    class_f1_score = f1_score(y_true_binary, predictions_binary)
    class_accuracies.append(class_accuracy)
    class_precisions.append(class_precision)
    class_recalls.append(class_recall)
    class_f1_scores.append(class_f1_score)

# Print the accuracy, precision, recall, and F1-score for each class
for class_index in range(num_classes):
    print(f"Class {class_index} Accuracy: {class_accuracies[class_index]:.4f}")
    print(f"Class {class_index} Precision: {class_precisions[class_index]:.4f}")
    print(f"Class {class_index} Recall: {class_recalls[class_index]:.4f}")
    print(f"Class {class_index} F1-score: {class_f1_scores[class_index]:.4f}")
# Out:
# 6/6 [==============================] - 2s 248ms/step
# Class 0 Accuracy: 0.7663
# Class 0 Precision: 0.6338
# Class 0 Recall: 0.7258
# Class 0 F1-score: 0.6767
# Class 1 Accuracy: 0.8043
# Class 1 Precision: 0.9231
# Class 1 Recall: 0.5217
# Class 1 F1-score: 0.6667
# Class 2 Accuracy: 0.8859
# Class 2 Precision: 0.7162
# Class 2 Recall: 1.0000
# Class 2 F1-score: 0.8346
